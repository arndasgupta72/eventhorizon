# %% [markdown]
# The code is written such that the test particle starts tangentially initially. This means that $\dot{r} = \dot{u} = 0$ initially. If we could ensure that $\dot{u}=0$ at all angular positions, then the orbit will be perfectly circular.
#
# This can be done by demanding that $\ddot{u} = 0$ i.e.
#
# $$ \dfrac{3GM}{c^2}u^2 - u +\dfrac{GM}{l^2}=0$$
#
# Solving the quadratic equation, we obtain two values of $u_0$ as :
#
# $$ u_0 = \dfrac{c^2}{6GM}\left[1\pm \sqrt{1-\dfrac{12G^2M^2}{c^2L^2}}\right]\implies r_0 = \dfrac{6GM}{c^2}\left[\dfrac{1}{1\pm \sqrt{1-\dfrac{12G^2M^2}{c^2L^2}}}\right] $$
#
# These two values of $r_0$ correspond to the stable (larger) and the unstable (smaller) circular orbits.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Physical Constants
G = 6.67430e-11
M = 1.989e30
c = 299792458
AU = 1.496e11
r_s = 2 * G * M / c**2

# %%
# Orbit Parameters (modifiable)
L = 1.8e12               # Angular momentum per unit mass

# Circular orbits
r_stable,r_unstable = 6*G*M/c**2*(1-(1-12*G**2*M**2/c**2/L**2)**0.5)**-1, 6*G*M/c**2*(1+(1-12*G**2*M**2/c**2/L**2)**0.5)**-1
print(f'Stable Circular Orbit at {r_stable/r_s} r_s')
print(f'Unstable Circular Orbit at {r_unstable/r_s} r_s')
# Out:
# Stable Circular Orbit at 6.2923118777117875 r_s
# Unstable Circular Orbit at 1.9695019976609534 r_s

# %%
# r0 = 1.969501997660954*r_s
r0 = r_unstable             # Initial distance
u0 = 1 / r0
v0 = 0                   # Initial radial derivative
y0 = np.array([u0, v0])  # Initial state vector

# %%
# Simulation parameters
h = 0.0001                # Step size
n_orbits = 80            # Number of orbits
phis = np.arange(0, 2 * np.pi * n_orbits, h)

# %%
# ODE system: dy/dx = f(x, y)
def schwarzschild_ode(phi, y):
    u, v = y
    du_dphi = v
    dv_dphi = G*M / L**2 + 3*G*M*u**2 / c**2 - u
    return np.array([du_dphi, dv_dphi])

# RK4 Integrator
def rk4_step(f, x, y, h):
    k1 = h * f(x, y)
    k2 = h * f(x + h/2, y + k1/2)
    k3 = h * f(x + h/2, y + k2/2)
    k4 = h * f(x + h, y + k3)
    return y + (k1 + 2*k2 + 2*k3 + k4) / 6

# Integration function
def integrate(f, xs, y0, h):
    ys = np.zeros((len(xs), 2))
    y = y0.copy()
    for i, x in enumerate(xs):
        ys[i] = y
        y = rk4_step(f, x, y, h)
    return ys

# %%
# Run simulation
sol = integrate(schwarzschild_ode, phis, y0, h)
u_vals = sol[:, 0]
r_vals = 1 / u_vals
r_AU = r_vals / AU

# %%
# event horizon

def event_horizon(r_s):
    thetas = np.linspace(0,2*np.pi,100)
    return r_s/AU*np.cos(thetas),r_s/AU*np.sin(thetas)

# %%
# Plot 1: Polar Plot
plt.figure(figsize=(6,6))
ax = plt.subplot(111, polar=True)
ax.plot(phis, r_AU, 'r--', label='Orbit')
ax.scatter([0], [0], color='yellow', label='Sun')
plt.title("Planetary Orbit (Polar)")
plt.legend()
plt.show()

# %%
# Cartesian coordinates
x_vals = r_AU * np.cos(phis)
y_vals = r_AU * np.sin(phis)
event_hor_x,event_hor_y = event_horizon(r_s)

# Plot 2: Cartesian Orbit
plt.figure(figsize=(6,6))
plt.plot(x_vals, y_vals, 'b--')
plt.plot(0, 0, 'ko', label='Sun')
plt.plot(event_hor_x,event_hor_y,linestyle = 'dotted',c = 'red' ,label = 'event_horizon')
plt.axhline(0, linestyle='--', color='gray')
plt.axvline(0, linestyle='--', color='gray')
plt.xlabel("x (AU)")
plt.ylabel("y (AU)")
plt.title("Planetary Orbit (Cartesian)")
plt.axis('equal')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Plot 3: r vs phi
plt.figure(figsize=(8,4))
plt.plot(phis/2/np.pi, r_AU, label='r(φ)')
plt.axhline(r_s / AU, color='r', linestyle='--', label=f'Schwarzschild Radius = {r_s/AU} AU')
plt.xlabel("number of revolutions")
plt.ylabel("r (AU)")
plt.title("Radial Distance vs Angular Position")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Closest approach and Schwarzschild check
min_r = np.min(r_vals)
print(f"Distance of Closest Approach = {min_r/1e3:.2f} km")
print(f"Schwarzschild Radius = {r_s/1e3:.2e} km")

if r_s < min_r:
    print("✓ The particle did not fall into the black hole.")
else:
    print("✗ The particle fell into the black hole.")
# Out:
# Distance of Closest Approach = 5.82 km
# Schwarzschild Radius = 2.95e+00 km
# ✓ The particle did not fall into the black hole.
